# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from oivis.oifits import oifits_read
from oivis.oifits import oifits_transform as oitrans
import importlib
import os

# %%
importlib.reload(oitrans)
importlib.reload(oifits_read)
# Out:
# <module 'oivis.oifits.oifits_read' from '/Users/bergejea/Software/tihpy/oivis/oifits/oifits_read.py'>

# %%
datadir = os.path.dirname(os.path.abspath(".")) + "/data/"

# %% [markdown]
# # Testing zone filtering
# Here cone search by angle and projected baseline in uv plane

# %%
# Loading
file = "2013-01-28_SCI_HD100546_oiDataCalib.fits"
oidatablocks = oifits_read.Oifits([datadir + file]).oidata
# selecting VIS2 data
oivis2datablocks = oitrans.filter_by_keyword(oidatablocks,"TYPE","V2")

# %%
# original data
oivis2data = oitrans.get_v2data(oivis2datablocks)
# Cone search in angle and radius
oivis2dataconeblocks = oitrans.filter_by_zone(oivis2datablocks,["THETA","BP"], [[0,40],[100,120]])
oivis2datacone = oitrans.get_v2data(oivis2dataconeblocks)

# %%
f = plt.figure(1, figsize=(12,8))
ax = plt.subplot(111, projection="polar")
ax.plot(np.deg2rad(oivis2datacone["THETA"]), oivis2datacone["BP"],'ro',alpha=0.3, markersize=12)
ax.plot(np.deg2rad(oivis2data["THETA"]), oivis2data["BP"],'o')
